# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)

# %%
iris_dataset=load_iris()
print("keys of iris dataset :\n {}".format(iris_dataset.keys()))

# %%
print(iris_dataset['DESCR'][:195]+"\n...")

# %%
print("target name : {}".format(iris_dataset['target_names']))# contins an array of string containing the species of flower that
                                                              # we want to predict:

# %%
print("feature names : \n{}".format(iris_dataset['feature_names']))#list of string,giving the discription of each feature

# %%
print("type of data: {}".format(type(iris_dataset['data'])))

# %%
print("shape of data : {}".format(iris_dataset['data'].shape))# it show 150 ,4 means it contains measurement of 150 different flowers

# %%
print("first five coloums of data : \n{}".format(iris_dataset['data'][:5]))

# %%
print("type of target :{}".format(type(iris_dataset['target'])))

# %%
print("type of target :{}".format(iris_dataset['target']))# target array contains the species of each of the f;ower that were measured

# %%
print("shape of target : {}".format(iris_dataset['target'].shape))

# %% [markdown]
# Measuring success : training and testing data
# we need to split the data set into two parts one will be used traing the model and the other part will be  use to test the model
# by using train_test_split we split the data in 75 % for training and the 25% for testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(iris_dataset['data'],iris_dataset['target'],random_state=0)

# %%
print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))

# %%
print("x_test shape: {}".format(x_test.shape))
print("y_test shape: {}".format(y_test.shape))

# %%
#creat dataframe from data in x_train
#lable the columns using the string in iris_dataset.feature_names

iris_dataframe=pd.DataFrame(x_train,columns=iris_dataset.feature_names)
#creat a scatter matrix from the dataframe ,color by y_train 
grr=scatter_matrix(
    iris_dataframe,
    c=y_train,
    figsize=(15,15),
    marker='o',
    hist_kwds={'bins':20},
    s=60,
    alpha=0.8,
    )

# %%
knn.fit(x_train,y_train)

# %%
X_new= np.array([[5,2.9,1,0.2]])
print("X_new.shape: {}".format(X_new.shape))

# %% [markdown]
# making predictions

# %%
prediction=knn.predict(X_new)
print("prediction : {}".format(prediction))
print("prediction target name:{}".format(iris_dataset['target_names'][prediction]))

# %% [markdown]
# evaluating the model

# %%
y_pred=knn.predict(x_test)
print("test set prediction: \n{}".format(y_pred))

# %%
print("test set score:{:.2f}".format(np.mean(y_pred==y_test)))

# %%
print("test set score : {:.2f}".format(knn.score(x_test,y_test)))
