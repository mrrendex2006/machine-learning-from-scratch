# %% [markdown]
# ## **MNIST dataset**
# ---
# A dataset which is a set of 70,000 small
# images of digits handwritten by high school students and employees of the US Cen
# sus Bureau. Each image is labeled with the digit it represents. This set has been stud
# ied so much that it is often called the “Hello World” of Machine Learning:

# %%
#Step1 . import essential libraries 
import pandas as pd 

from sklearn.datasets import fetch_openml

# %%
mnist=fetch_openml('mnist_784', version=1, as_frame=False)
x,y = minst.data , minst.target
