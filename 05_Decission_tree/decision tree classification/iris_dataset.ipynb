# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#dependent and indipendent features 
X=df.iloc[:,:-1]
y=df['species']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from  sklearn.tree import DecisionTreeClassifier
treemodel=DecisionTreeClassifier(max_depth=2)#we do not need to split to the last leaf node 
                          # already seen without hyperparamenter max_depth 
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# here providing hyperparameter is known as post prunning

# %%
tree_predict=treemodel.predict(X_test)

# %%
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.666\nsamples = 100\nvalue = [31, 35, 34]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 69\nvalue = [0, 35, 34]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.188\nsamples = 38\nvalue = [0, 34, 4]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.062\nsamples = 31\nvalue = [0, 1, 30]')]

# %%
from sklearn.metrics import classification_report,accuracy_score
print("---------Accuracy :",accuracy_score(y_test,tree_predict))
print("---------classification report :-\n",classification_report(y_test,tree_predict))
# Out:
# ---------Accuracy : 0.98
# ---------classification report :-
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %% [markdown]
# now lets check for best parameters best fit for our iris dataset for decision tree . we will apply gridsearch cv and try pre prunning by providing parameter before traing our model

# %%
parameter={
    'criterion':['gini','entropy','log_loss'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4],
    'max_features':['auto','sqrt','log2'],
    
}

# %%
from sklearn.model_selection import GridSearchCV
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,scoring='accuracy')

# %%
cv.fit(X_train,y_train)
# Out:
# C:\Users\nidhi\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 120 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\nidhi\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nidhi\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# ...

# %%
cv.best_params_ # it gives the best combination of paramenter that best fit the data
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'splitter': 'random'}

# %%
y_pred=cv.predict(X_test)

# %%
print("---------Accuracy :",accuracy_score(y_test,y_pred))
print("---------classification report :-\n",classification_report(y_test,y_pred))
# Out:
# ---------Accuracy : 0.98
# ---------classification report :-
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
